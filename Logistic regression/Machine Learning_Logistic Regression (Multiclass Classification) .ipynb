# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("D:/Downloads/Iris_dataset for logistic regrassion.csv")

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 6 columns]

# %%
df['Species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
df['Species'].replace({'Iris-setosa':'1','Iris-versicolor':'2','Iris-virginica':'3'},inplace=True)

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm Species
# 0      1            5.1           3.5            1.4           0.2       1
# 1      2            4.9           3.0            1.4           0.2       1
# 2      3            4.7           3.2            1.3           0.2       1
# 3      4            4.6           3.1            1.5           0.2       1
# 4      5            5.0           3.6            1.4           0.2       1
# ..   ...            ...           ...            ...           ...     ...
# 145  146            6.7           3.0            5.2           2.3       3
# 146  147            6.3           2.5            5.0           1.9       3
# 147  148            6.5           3.0            5.2           2.0       3
# 148  149            6.2           3.4            5.4           2.3       3
# 149  150            5.9           3.0            5.1           1.8       3
#
# [150 rows x 6 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(df[['SepalLengthCm', 'SepalWidthCm','PetalLengthCm','PetalWidthCm']],df['Species'],test_size=0.2)

# %%
x_train
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 99             5.7           2.8            4.1           1.3
# 34             4.9           3.1            1.5           0.1
# 95             5.7           3.0            4.2           1.2
# 127            6.1           3.0            4.9           1.8
# 31             5.4           3.4            1.5           0.4
# ..             ...           ...            ...           ...
# 77             6.7           3.0            5.0           1.7
# 28             5.2           3.4            1.4           0.2
# 3              4.6           3.1            1.5           0.2
# 74             6.4           2.9            4.3           1.3
# 116            6.5           3.0            5.5           1.8
#
# [120 rows x 4 columns]

# %%
y_train
# Out:
# 99     2
# 34     1
# 95     2
# 127    3
# 31     1
#       ..
# 77     2
# 28     1
# 3      1
# 74     2
# 116    3
# Name: Species, Length: 120, dtype: object

# %%
len(x_train)
# Out:
# 120

# %%
len(x_test)
# Out:
# 30

# %%
len(y_train)
# Out:
# 120

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr =  LogisticRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# C:\Users\abida\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
lr.predict(x_test)
# Out:
# array(['2', '3', '1', '1', '3', '3', '1', '3', '2', '3', '2', '3', '3',
#        '3', '2', '2', '2', '1', '2', '3', '2', '2', '3', '1', '3', '2',
#        '3', '2', '1', '2'], dtype=object)

# %%
 x_test
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 73             6.1           2.8            4.7           1.2
# 110            6.5           3.2            5.1           2.0
# 13             4.3           3.0            1.1           0.1
# 14             5.8           4.0            1.2           0.2
# 146            6.3           2.5            5.0           1.9
# 109            7.2           3.6            6.1           2.5
# 9              4.9           3.1            1.5           0.1
# 120            6.9           3.2            5.7           2.3
# 62             6.0           2.2            4.0           1.0
# 101            5.8           2.7            5.1           1.9
# 84             5.4           3.0            4.5           1.5
# 117            7.7           3.8            6.7           2.2
# 113            5.7           2.5            5.0           2.0
# 111            6.4           2.7            5.3           1.9
# 90             5.5           2.6            4.4           1.2
# 72             6.3           2.5            4.9           1.5
# 94             5.6           2.7            4.2           1.3
# 18             5.7           3.8            1.7           0.3
# 106            4.9           2.5            4.5           1.7
# 149            5.9           3.0            5.1           1.8
# 59             5.2           2.7            3.9           1.4
# 88             5.6           3.0            4.1           1.3
# 122            7.7           2.8            6.7           2.0
# 17             5.1           3.5            1.4           0.3
# 134            6.1           2.6            5.6           1.4
# 61             5.9           3.0            4.2           1.5
# 136            6.3           3.4            5.6           2.4
# 91             6.1           3.0            4.6           1.4
# 1              4.9           3.0            1.4           0.2
# 98             5.1           2.5            3.0           1.1

# %%
 lr.score(x_test,y_test)
# Out:
# 0.9666666666666667

# %%
import seaborn as sns

# %%
sns.pairplot(df[['SepalLengthCm', 'SepalWidthCm','PetalLengthCm','PetalWidthCm','Species']],hue='Species')
