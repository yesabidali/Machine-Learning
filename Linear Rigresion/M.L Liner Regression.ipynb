# %%
#to predict insaurace value
import pandas as pd
import seaborn as sns
from sklearn import linear_model

# %%
x= pd.read_csv("D:/Downloads/Book1.csv")
print(x)
# Out:
#    age  Insurance
# 0   25      18000
# 1   30      32000
# 2   35      40000
# 3   40      47000
# 4   45      55000

# %%
sns.lmplot(x="age", y="Insurance" , data=x)

# %%
reg=linear_model.LinearRegression()

# %%
reg.fit(x[["age"]],x["Insurance"])
# Out:
# LinearRegression()

# %%
reg.predict([[21]])
# Out:
# C:\Users\abida\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([13480.])

# %%
reg.predict([[50]])
# Out:
# C:\Users\abida\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([65100.])

# %%
reg.coef_
# Out:
# array([1780.])

# %%
reg.intercept_
# Out:
# -23900.0
